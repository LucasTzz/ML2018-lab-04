# %%
from numpy import *
import math
def load_data(path):
    f = open(path)
    data = []
    for line in f.readlines():
        arr = []
        lines = line.strip().split("\t")
        for x in lines:
            arr.append(x)
        data.append(arr)
    return data

# load data from the dataset
pre_train=load_data('./ml-100k/u1.base')
pre_val=load_data('./ml-100k/u1.test')
n_users=943
n_item=1682

# %%
#initialize training matrix and validation matrix
R_train=zeros((n_users,n_item))
R_val=zeros((n_users,n_item))
for i in pre_train:
    user_id=int(i[0])-1
    item_id=int(i[1])-1
    rating=float(i[2])
    R_train[user_id][item_id]=rating
for i in pre_val:
    user_id=int(i[0])-1
    item_id=int(i[1])-1
    rating=float(i[2])
    R_val[user_id][item_id]=rating
#initialize parameters
K=20
alpha=0.2
lamda_p=0.02
lamda_q=0.01
max_epoch=200
# create user and item matrices
P_users=random.random((n_users,K))
Q_item=random.random((n_item,K))
R_train=mat(R_train)
R_val=mat(R_val)
P_users=mat(P_users)
Q_item=mat(Q_item)

# %%
# define loss function
def loss(P,Q,R):
    error=0
    sum_of_P=0
    sum_of_Q=0
    n_p=[]
    n_q=[]
    for i in range(n_users):
        n=0
        for j in range(n_item):
            if R[i,j]>0:
                error+=square(R[i,j]-(P[i]*Q[j].T)[0,0])
                n+=1 #calculate total ratings of a certain user i
        n_p.append(n)
        sum_of_P+=square(linalg.norm(P[i]))*n_p[i]

    for j in range(n_item):
        n=0
        for i in range(n_users):
            if R[i,j]>0:
                n+=1
        n_q.append(n)
        sum_of_Q+=square(linalg.norm(Q[j]))*n_q[j]
    error+=lamda_p*sum_of_P+lamda_q*sum_of_Q #normalization
    return error,n_p,n_q

# %%
# Mean Absolute Error
def MAE():
    n=0
    error=0
    for i in range(n_users):
        for j in range(n_item):
            if R_val[i,j]>0:
                error+=abs(R_val[i,j]-(P_users[i]*Q_item[j].T)[0,0])
                n+=1
    Loss=error/n
    return Loss
# Root Mean Square Error
def RMSE():
    n=0
    error=0
    for i in range(n_users):
        for j in range(n_item):
            if R_val[i,j]>0:
                error+=square(R_val[i,j]-(P_users[i]*Q_item[j].T)[0,0])
                n+=1
    Loss=sqrt(error/n)
    return Loss

# %%
MAE_val=[]
RMSE_val=[]
L_trainings=[]
for epoch in range(max_epoch):
    # select a sample randomly
    i=random.randint(1,n_users)
    j=random.randint(1,n_item)
    # calculate gradient on this sample
    error=R_train[i,j]-(P_users[i]*Q_item[j].T)[0,0]
    G_p=-1*error*Q_item[j]+lamda_p*P_users[i]
    G_q=-1*error*P_users[i]+lamda_q*Q_item[j]
    # update vectors in P and Q
    P_users[i]-=alpha*G_p
    Q_item[j]-=alpha*G_q
    L_training=loss(P_users,Q_item,R_train)[0]
    L_validation_RMSE=RMSE()
    L_validation_MAE=MAE()
    # exponential decay periodically
    if epoch%5==0:
        alpha/=2
    print('The current loss of validation is: ',L_validation_RMSE,'\tepoch: ',epoch)
    MAE_val.append(L_validation_MAE)
    RMSE_val.append(L_validation_RMSE)
    L_trainings.append(L_training)
# Out:
# The current loss of validation is:  2.180623709767404 	epoch:  0
# The current loss of validation is:  2.1808154932707393 	epoch:  1
# The current loss of validation is:  2.1802084709295593 	epoch:  2
# The current loss of validation is:  2.1793620225845514 	epoch:  3
# The current loss of validation is:  2.1793620225845514 	epoch:  4
# The current loss of validation is:  2.1790162465934784 	epoch:  5
# The current loss of validation is:  2.178576945896244 	epoch:  6
# The current loss of validation is:  2.1732096143651116 	epoch:  7
# The current loss of validation is:  2.172240634258638 	epoch:  8
# The current loss of validation is:  2.172195968926598 	epoch:  9
# The current loss of validation is:  2.1723566986813037 	epoch:  10
# The current loss of validation is:  2.1723330699642416 	epoch:  11
# The current loss of validation is:  2.1722027054124506 	epoch:  12
# The current loss of validation is:  2.1722425764452367 	epoch:  13
# The current loss of validation is:  2.1722415792895653 	epoch:  14
# The current loss of validation is:  2.171962424946588 	epoch:  15
# The current loss of validation is:  2.1716240759271974 	epoch:  16
# The current loss of validation is:  2.1716043538827714 	epoch:  17
# The current loss of validation is:  2.1705758287102848 	epoch:  18
# The current loss of validation is:  2.1705593908766336 	epoch:  19
# The current loss of validation is:  2.1705649847956052 	epoch:  20
# The current loss of validation is:  2.1705649847956052 	epoch:  21
# The current loss of validation is:  2.170504566583394 	epoch:  22
# The current loss of validation is:  2.1702282016109824 	epoch:  23
# The current loss of validation is:  2.170227768601145 	epoch:  24
# The current loss of validation is:  2.170032181271012 	epoch:  25
# The current loss of validation is:  2.170032181271012 	epoch:  26
# The current loss of validation is:  2.1698866286198815 	epoch:  27
# The current loss of validation is:  2.1698322884232644 	epoch:  28
# The current loss of validation is:  2.16982601666909 	epoch:  29
# The current loss of validation is:  2.169643285217727 	epoch:  30
# The current loss of validation is:  2.169565228463305 	epoch:  31
# The current loss of validation is:  2.169553841733317 	epoch:  32
# The current loss of validation is:  2.169513492331113 	epoch:  33
# The current loss of validation is:  2.169523721816818 	epoch:  34
# The current loss of validation is:  2.1693112886214307 	epoch:  35
# The current loss of validation is:  2.169310814834999 	epoch:  36
# The current loss of validation is:  2.16930699682154 	epoch:  37
# The current loss of validation is:  2.169271411268212 	epoch:  38
# The current loss of validation is:  2.1691955805239256 	epoch:  39
# The current loss of validation is:  2.1691936366198257 	epoch:  40
# The current loss of validation is:  2.1691802671699754 	epoch:  41
# The current loss of validation is:  2.169178298535588 	epoch:  42
# The current loss of validation is:  2.1691666018731484 	epoch:  43
# The current loss of validation is:  2.1691666018731484 	epoch:  44
# The current loss of validation is:  2.1691582332053474 	epoch:  45
# The current loss of validation is:  2.169155493376045 	epoch:  46
# The current loss of validation is:  2.1691543541235223 	epoch:  47
# The current loss of validation is:  2.1691495246669064 	epoch:  48
# The current loss of validation is:  2.16914732465437 	epoch:  49
# The current loss of validation is:  2.169142025527413 	epoch:  50
# The current loss of validation is:  2.1691401589432067 	epoch:  51
# The current loss of validation is:  2.1691379399901605 	epoch:  52
# The current loss of validation is:  2.1691281965259237 	epoch:  53
# The current loss of validation is:  2.1691238403629245 	epoch:  54
# The current loss of validation is:  2.169123383159366 	epoch:  55
# The current loss of validation is:  2.169123312923995 	epoch:  56
# The current loss of validation is:  2.1691231844205965 	epoch:  57
# The current loss of validation is:  2.1691230191086355 	epoch:  58
# The current loss of validation is:  2.169122117292272 	epoch:  59
# The current loss of validation is:  2.1691220306449726 	epoch:  60
# The current loss of validation is:  2.169121945452386 	epoch:  61
# The current loss of validation is:  2.1691219272862967 	epoch:  62
# The current loss of validation is:  2.1691218356237143 	epoch:  63
# The current loss of validation is:  2.169120594903474 	epoch:  64
# The current loss of validation is:  2.169118401374686 	epoch:  65
# The current loss of validation is:  2.1691183468360067 	epoch:  66
# The current loss of validation is:  2.169118299427813 	epoch:  67
# The current loss of validation is:  2.1691180405572843 	epoch:  68
# The current loss of validation is:  2.1691172987286174 	epoch:  69
# The current loss of validation is:  2.169116819392484 	epoch:  70
# The current loss of validation is:  2.1691167851892046 	epoch:  71
# The current loss of validation is:  2.1691167085822824 	epoch:  72
# The current loss of validation is:  2.1691165904567313 	epoch:  73
# The current loss of validation is:  2.169116565387615 	epoch:  74
# The current loss of validation is:  2.1691163720769584 	epoch:  75
# The current loss of validation is:  2.1691163720769584 	epoch:  76
# The current loss of validation is:  2.169116370728314 	epoch:  77
# The current loss of validation is:  2.169116370728314 	epoch:  78
# The current loss of validation is:  2.1691163454128053 	epoch:  79
# The current loss of validation is:  2.16911613091033 	epoch:  80
# The current loss of validation is:  2.1691161003888664 	epoch:  81
# The current loss of validation is:  2.1691160876103623 	epoch:  82
# The current loss of validation is:  2.169116063679593 	epoch:  83
# The current loss of validation is:  2.1691160389282214 	epoch:  84
# The current loss of validation is:  2.1691160389282214 	epoch:  85
# The current loss of validation is:  2.1691159215741997 	epoch:  86
# The current loss of validation is:  2.1691159215741997 	epoch:  87
# The current loss of validation is:  2.1691159200057357 	epoch:  88
# The current loss of validation is:  2.1691159200057357 	epoch:  89
# The current loss of validation is:  2.1691159184665603 	epoch:  90
# The current loss of validation is:  2.1691159143323033 	epoch:  91
# The current loss of validation is:  2.1691159107128906 	epoch:  92
# The current loss of validation is:  2.169115909023105 	epoch:  93
# The current loss of validation is:  2.169115904271444 	epoch:  94
# The current loss of validation is:  2.169115897599652 	epoch:  95
# The current loss of validation is:  2.169115896698597 	epoch:  96
# The current loss of validation is:  2.169115896040921 	epoch:  97
# The current loss of validation is:  2.169115896040921 	epoch:  98
# The current loss of validation is:  2.16911589492155 	epoch:  99
# The current loss of validation is:  2.1691158941503907 	epoch:  100
# The current loss of validation is:  2.1691158832535145 	epoch:  101
# The current loss of validation is:  2.169115882087352 	epoch:  102
# The current loss of validation is:  2.1691158771476236 	epoch:  103
# The current loss of validation is:  2.169115876936548 	epoch:  104
# The current loss of validation is:  2.1691158733567097 	epoch:  105
# The current loss of validation is:  2.169115870493041 	epoch:  106
# The current loss of validation is:  2.16911586940147 	epoch:  107
# The current loss of validation is:  2.1691158688928285 	epoch:  108
# The current loss of validation is:  2.1691158684307803 	epoch:  109
# The current loss of validation is:  2.1691158661099266 	epoch:  110
# The current loss of validation is:  2.169115865424851 	epoch:  111
# The current loss of validation is:  2.1691158651647204 	epoch:  112
# The current loss of validation is:  2.169115864557651 	epoch:  113
# The current loss of validation is:  2.1691158644322686 	epoch:  114
# The current loss of validation is:  2.1691158641556214 	epoch:  115
# The current loss of validation is:  2.1691158640847936 	epoch:  116
# The current loss of validation is:  2.1691158630139933 	epoch:  117
# The current loss of validation is:  2.1691158629598353 	epoch:  118
# The current loss of validation is:  2.169115862747174 	epoch:  119
# The current loss of validation is:  2.169115862486203 	epoch:  120
# The current loss of validation is:  2.169115862486203 	epoch:  121
# The current loss of validation is:  2.1691158622670867 	epoch:  122
# The current loss of validation is:  2.169115862272794 	epoch:  123
# The current loss of validation is:  2.16911586206497 	epoch:  124
# The current loss of validation is:  2.1691158620640323 	epoch:  125
# The current loss of validation is:  2.169115862068324 	epoch:  126
# The current loss of validation is:  2.1691158620077253 	epoch:  127
# The current loss of validation is:  2.169115861709016 	epoch:  128
# The current loss of validation is:  2.1691158615495967 	epoch:  129
# The current loss of validation is:  2.1691158614652117 	epoch:  130
# The current loss of validation is:  2.1691158614647126 	epoch:  131
# The current loss of validation is:  2.1691158614554227 	epoch:  132
# The current loss of validation is:  2.1691158614336072 	epoch:  133
# The current loss of validation is:  2.169115861375959 	epoch:  134
# The current loss of validation is:  2.169115861360934 	epoch:  135
# The current loss of validation is:  2.169115861363191 	epoch:  136
# The current loss of validation is:  2.169115861327524 	epoch:  137
# The current loss of validation is:  2.1691158612539065 	epoch:  138
# The current loss of validation is:  2.169115861238196 	epoch:  139
# The current loss of validation is:  2.169115861233415 	epoch:  140
# The current loss of validation is:  2.1691158612317745 	epoch:  141
# The current loss of validation is:  2.1691158612324517 	epoch:  142
# The current loss of validation is:  2.1691158612286783 	epoch:  143
# The current loss of validation is:  2.1691158612288124 	epoch:  144
# The current loss of validation is:  2.169115861213543 	epoch:  145
# The current loss of validation is:  2.169115861213543 	epoch:  146
# The current loss of validation is:  2.1691158612122328 	epoch:  147
# The current loss of validation is:  2.1691158612000336 	epoch:  148
# The current loss of validation is:  2.169115861181556 	epoch:  149
# The current loss of validation is:  2.169115861180783 	epoch:  150
# The current loss of validation is:  2.169115861180761 	epoch:  151
# The current loss of validation is:  2.1691158611801353 	epoch:  152
# The current loss of validation is:  2.1691158611800154 	epoch:  153
# The current loss of validation is:  2.1691158611757184 	epoch:  154
# The current loss of validation is:  2.1691158611756896 	epoch:  155
# The current loss of validation is:  2.1691158611754475 	epoch:  156
# The current loss of validation is:  2.169115861175265 	epoch:  157
# The current loss of validation is:  2.1691158611749026 	epoch:  158
# The current loss of validation is:  2.1691158611747396 	epoch:  159
# The current loss of validation is:  2.1691158611739376 	epoch:  160
# The current loss of validation is:  2.1691158611737933 	epoch:  161
# The current loss of validation is:  2.1691158611737933 	epoch:  162
# The current loss of validation is:  2.169115861173695 	epoch:  163
# The current loss of validation is:  2.169115861173622 	epoch:  164
# The current loss of validation is:  2.1691158611727 	epoch:  165
# The current loss of validation is:  2.169115861172674 	epoch:  166
# The current loss of validation is:  2.1691158611726427 	epoch:  167
# The current loss of validation is:  2.169115861172509 	epoch:  168
# The current loss of validation is:  2.169115861172067 	epoch:  169
# The current loss of validation is:  2.169115861171088 	epoch:  170
# The current loss of validation is:  2.1691158611710786 	epoch:  171
# The current loss of validation is:  2.169115861170985 	epoch:  172
# The current loss of validation is:  2.16911586117086 	epoch:  173
# The current loss of validation is:  2.169115861170445 	epoch:  174
# The current loss of validation is:  2.169115861170434 	epoch:  175
# The current loss of validation is:  2.169115861170413 	epoch:  176
# The current loss of validation is:  2.1691158611704098 	epoch:  177
# The current loss of validation is:  2.1691158611703893 	epoch:  178
# The current loss of validation is:  2.16911586117039 	epoch:  179
# The current loss of validation is:  2.1691158611702646 	epoch:  180
# The current loss of validation is:  2.169115861170261 	epoch:  181
# The current loss of validation is:  2.1691158611701864 	epoch:  182
# The current loss of validation is:  2.1691158611701624 	epoch:  183
# The current loss of validation is:  2.169115861170058 	epoch:  184
# The current loss of validation is:  2.169115861170056 	epoch:  185
# The current loss of validation is:  2.169115861170049 	epoch:  186
# The current loss of validation is:  2.1691158611699906 	epoch:  187
# The current loss of validation is:  2.169115861169956 	epoch:  188
# The current loss of validation is:  2.169115861169935 	epoch:  189
# The current loss of validation is:  2.1691158611699306 	epoch:  190
# The current loss of validation is:  2.1691158611699293 	epoch:  191
# The current loss of validation is:  2.169115861169893 	epoch:  192
# The current loss of validation is:  2.1691158611698893 	epoch:  193
# The current loss of validation is:  2.1691158611698853 	epoch:  194
# The current loss of validation is:  2.169115861169877 	epoch:  195
# The current loss of validation is:  2.1691158611698755 	epoch:  196
# The current loss of validation is:  2.1691158611698635 	epoch:  197
# The current loss of validation is:  2.169115861169863 	epoch:  198
# The current loss of validation is:  2.1691158611698547 	epoch:  199

# %%
import matplotlib.pyplot as plt
# show in graph
plt.figure(figsize=(18, 6))
plt.plot(L_trainings, color="r", label="Loss on training set")
#plt.plot(RMSE_val, color="b", label="Lvalidation by RMSE")
plt.legend()
plt.xlabel("epoch")
plt.ylabel("loss")
plt.title("The graph of loss value varing with the number of iterations")
plt.show()

# %%
#calculate the final prediction matrix
R_predict=P_users*Q_item.T
print(R_predict)
# Out:
# [[5.84260523 6.82198411 6.34419141 ... 2.88914952 5.09969017 7.44549266]
#  [5.42073439 6.14928751 5.81057754 ... 2.09057562 4.39174653 6.89080069]
#  [6.30026701 6.76451748 6.91421762 ... 2.94534054 4.9397144  8.10705146]
#  ...
#  [5.61845203 6.26403038 5.72833547 ... 2.36965044 3.81366153 6.4840805 ]
#  [5.31319519 5.94963829 5.47392085 ... 2.45708789 4.70937681 6.27481008]
#  [6.28572966 6.1806177  6.00480812 ... 2.46028457 4.66980725 8.02800965]]
